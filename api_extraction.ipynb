# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (from spotipy) (1.26.4)
# Requirement already satisfied: requests>=2.25.0 in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (from spotipy) (2.25.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2020.6.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vijaya madhuri t a\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.0.4)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials 
client_id = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
client_secret = "yyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
name = ["Micheal Jackson","pitbull","Christina","Elvis Presley"]
result = sp.search(name) 
result['tracks']['items'][1]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27XaM1Qqd3zfxJ82cbQ1FK'},
#   'href': 'https://api.spotify.com/v1/artists/27XaM1Qqd3zfxJ82cbQ1FK',
#   'id': '27XaM1Qqd3zfxJ82cbQ1FK',
#   'name': 'Micheal Jackson For Siegfried',
#   'type': 'artist',
#   'uri': 'spotify:artist:27XaM1Qqd3zfxJ82cbQ1FK'}]

# %%
artists_uris = result['tracks']['items'][0]['artists'][0]['uri']
artist_albums = sp.artist_albums(artists_uris, album_type='album')
artist_album_names = []
artist_album_uris = []
for i in range(len(artist_albums['items'])):
    artist_album_names.append(artist_albums['items'][i]['name'])
    artist_album_uris.append(artist_albums['items'][i]['uri'])

# %%
artist_album_names
# Out:
# ['Scream',
#  'XSCAPE',
#  'XSCAPE',
#  'XSCAPE - Track by Track Commentary',
#  'Michael',
#  'Invincible',
#  'BLOOD ON THE DANCE FLOOR/ HIStory In The Mix',
#  'BLOOD ON THE DANCE FLOOR/ HIStory In The Mix',
#  'Manila 1996',
#  'HIStory - PAST, PRESENT AND FUTURE - BOOK I',
#  'HIStory - PAST, PRESENT AND FUTURE - BOOK I',
#  'Dangerous',
#  'Bad (Remastered)',
#  'Bad 25th Anniversary',
#  'Thriller',
#  'Thriller',
#  'Thriller 25 Super Deluxe Edition',
#  'Off the Wall',
#  'Forever Michael',
#  'Forever, Michael']

# %%
artist_album_uris
# Out:
# ['spotify:album:2X8UOIkZQdcz2Hi5Ynt2uk',
#  'spotify:album:5sXEWtPp2JZG88ji9bLmwZ',
#  'spotify:album:7pomP86PUhoJpY3fsC0WDQ',
#  'spotify:album:54WFfZzds26NrwcmStfamd',
#  'spotify:album:0yYWeLqonFk11pmb0RiMbP',
#  'spotify:album:52E4RP7XDzalpIrOgSTgiQ',
#  'spotify:album:0RNsFWWdiz1rrdLI1pwbvJ',
#  'spotify:album:6BYNnU3IYdmYCNHtvlFngH',
#  'spotify:album:3T1JYXVBJiGCyTpeGk6ekt',
#  'spotify:album:3OBhnTLrvkoEEETjFA3Qfk',
#  'spotify:album:3Y4ZambRFbDzlnCtqEUrgY',
#  'spotify:album:0oX4SealMgNXrvRDhqqOKg',
#  'spotify:album:3Us57CjssWnHjTUIXBuIeH',
#  'spotify:album:24TAupSNVWSAHL0R7n71vm',
#  'spotify:album:2ANVost0y2y52ema1E9xAZ',
#  'spotify:album:5Ne1SPpiXQqpCZ6pZCRfIM',
#  'spotify:album:1C2h7mLntPSeVYciMRTF4a',
#  'spotify:album:2ZytN2cY4Zjrr9ukb2rqTP',
#  'spotify:album:3dZ91ooVpNEdukDWuNzbpZ',
#  'spotify:album:6leeBdAohG7zhybC3Cmu8W']

# %%
def album_songs(uri):
    album = uri 
    spotify_albums[album] = {}
    spotify_albums[album]['album'] = [] 
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    tracks = sp.album_tracks(album) 
    for n in range(len(tracks['items'])): 
        spotify_albums[album]['album'].append(artist_album_names[album_count]) 
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0
for i in artist_album_uris:
    album_songs(i)
    print(str(artist_album_names[album_count]) + " album songs has been added to spotify_albums dictionary")
# Out:
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary
# Scream album songs has been added to spotify_albums dictionary

# %%
def audio_features(album):
  
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    
    track_count = 0
    for track in spotify_albums[album]['uri']:
        features = sp.audio_features(track)
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 16.868816375732422 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 40.71762537956238 seconds
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 64.85462880134583 seconds
# 20 playlists completed
# Loop #: 20
# Elapsed Time: 82.89375591278076 seconds

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 299

# %%
import pandas as pd
dataframe = pd.DataFrame.from_dict(dic_df)
dataframe
# Out:
#       album  track_number                      id  \
# 0    Scream             1  2BU4dK1fu1CFLjTBz7ju7Q
# 1    Scream             2  7azo4rpSUh8nXgtonC6Pkq
# 2    Scream             3  0QgsvILuE9VQiAVsLStD3W
# 3    Scream             4  6A4Jc8npNo79BOgsrPptLA
# 4    Scream             5  4FC7GMnGwYeAjuvC83Srbs
# ..      ...           ...                     ...
# 294  Scream             6  5u4kX7qmMLc4qN8xfr0pT9
# 295  Scream             7  36DLONTcnfObcVEytGjymm
# 296  Scream             8  7xSCBsSlvGhMvJa5MtKLVU
# 297  Scream             9  2cpYpgS7V9z1uoTBA8FOhQ
# 298  Scream            10  3QAw8W7F2jSMjsJGAXvNCP
#
#                                            name  \
# 0    This Place Hotel (a.k.a. Heartbreak Hotel)
# 1                                      Thriller
# 2                      Blood on the Dance Floor
# 3       Somebody's Watching Me - Single Version
# 4                   Dirty Diana - 2012 Remaster
# ..                                          ...
# 294                    Just A Little Bit Of You
# 295                               You Are There
# 296                                  Dapper Dan
# 297                                Dear Michael
# 298                       I'll Come Home To You
#
#                                       uri  acousticness  danceability  energy  \
# 0    spotify:track:2BU4dK1fu1CFLjTBz7ju7Q        0.2430         0.730   0.851
# 1    spotify:track:7azo4rpSUh8nXgtonC6Pkq        0.0816         0.764   0.887
# 2    spotify:track:0QgsvILuE9VQiAVsLStD3W        0.0146         0.806   0.816
# 3    spotify:track:6A4Jc8npNo79BOgsrPptLA        0.0409         0.767   0.712
# 4    spotify:track:4FC7GMnGwYeAjuvC83Srbs        0.1780         0.735   0.801
# ..                                    ...           ...           ...     ...
# 294  spotify:track:5u4kX7qmMLc4qN8xfr0pT9        0.5700         0.735   0.673
# 295  spotify:track:36DLONTcnfObcVEytGjymm        0.2950         0.302   0.491
# 296  spotify:track:7xSCBsSlvGhMvJa5MtKLVU        0.0142         0.623   0.634
# 297  spotify:track:2cpYpgS7V9z1uoTBA8FOhQ        0.2730         0.549   0.604
# 298  spotify:track:3QAw8W7F2jSMjsJGAXvNCP        0.2620         0.450   0.659
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0            0.000143    0.1170    -4.085       0.1010   97.000    0.578
# 1            0.000110    0.8470    -3.726       0.0744  118.427    0.720
# 2            0.009330    0.0623    -2.767       0.0764  108.980    0.519
# 3            0.000081    0.1320    -4.128       0.0324  124.092    0.804
# 4            0.000408    0.3240    -4.525       0.0437  131.425    0.331
# ..                ...       ...       ...          ...      ...      ...
# 294          0.000000    0.0887    -9.703       0.0343  110.150    0.919
# 295          0.000078    0.1050    -8.352       0.0327   89.145    0.257
# 296          0.000000    0.2800    -9.257       0.0692  161.206    0.827
# 297          0.000004    0.1680    -8.421       0.0319  143.206    0.639
# 298          0.000014    0.2160   -10.021       0.0403   99.833    0.462
#
#      popularity
# 0            57
# 1            69
# 2            46
# 3             6
# 4            63
# ..          ...
# 294          22
# 295          20
# 296          20
# 297          21
# 298          19
#
# [299 rows x 15 columns]

# %%
print(len(dataframe))
final_df = dataframe.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 299
# 182

# %%
final_df.head()
# Out:
#     album  track_number                      id  \
# 0  Scream             1  2BU4dK1fu1CFLjTBz7ju7Q
# 1  Scream             2  7azo4rpSUh8nXgtonC6Pkq
# 3  Scream             4  6A4Jc8npNo79BOgsrPptLA
# 4  Scream             5  4FC7GMnGwYeAjuvC83Srbs
# 5  Scream             6  0XOuVAHsANAWw0LF0Yxkw5
#
#                                          name  \
# 0  This Place Hotel (a.k.a. Heartbreak Hotel)
# 1                                    Thriller
# 3     Somebody's Watching Me - Single Version
# 4                 Dirty Diana - 2012 Remaster
# 5                                     Torture
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:2BU4dK1fu1CFLjTBz7ju7Q        0.2430         0.730   0.851
# 1  spotify:track:7azo4rpSUh8nXgtonC6Pkq        0.0816         0.764   0.887
# 3  spotify:track:6A4Jc8npNo79BOgsrPptLA        0.0409         0.767   0.712
# 4  spotify:track:4FC7GMnGwYeAjuvC83Srbs        0.1780         0.735   0.801
# 5  spotify:track:0XOuVAHsANAWw0LF0Yxkw5        0.0179         0.754   0.836
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000143     0.117    -4.085       0.1010   97.000    0.578
# 1          0.000110     0.847    -3.726       0.0744  118.427    0.720
# 3          0.000081     0.132    -4.128       0.0324  124.092    0.804
# 4          0.000408     0.324    -4.525       0.0437  131.425    0.331
# 5          0.000003     0.350    -4.703       0.0425  131.130    0.965
#
#    popularity
# 0          57
# 1          69
# 3           6
# 4          63
# 5          55

# %%
final_df.to_csv("spotify_music.csv")
